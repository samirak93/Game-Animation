# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Game Animation

# %%
from Animation.game_animation import make_plot
from bokeh.io import show, output_notebook
import pandas as pd
from functools import partial

output_notebook()

df = pd.read_csv("sample_data/sample_basketball.csv")
image_url=["static/images/basketball.png"]

id_def=65
id_att=37
x_range=(0,94)
y_range=(0,50)

make_anim_plot = partial(make_plot, df=df, id_def = id_def, id_att = id_att,
                           headers = ["x", "y", "team_id", "player_id","time"], 
                           image_url=image_url, slider_steps=1,sport='basketball', 
                           x_range=x_range,y_range=y_range, anim_speed=50,show_dist_speed=False)

show(make_anim_plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# <script src="http://localhost:56477/autoload.js?bokeh-autoload-element=1002&bokeh-absolute-url=http://localhost:56477&resources=none" id="1002"></script>

# %% [markdown]
# ### Visualizing player markings

# %%
from Animation.player_marking import player_marking

make_anim_plot = partial(player_marking, df=df,image_url=image_url, id_def=id_def, id_att = id_att,
                           x_range=x_range, y_range=y_range, slider_steps=1,
                           headers = ["x", "y", "team_id", "player_id","time"], 
                           anim_speed=60, attack=True,sport='basketball')

show(make_anim_plot)
# Out:
# <script src="http://localhost:56489/autoload.js?bokeh-autoload-element=1287&bokeh-absolute-url=http://localhost:56489&resources=none" id="1287"></script>

# %% [markdown]
# ### Getting player marking related stats

# %%
from Animation.marking_details import marking_stats


marking = marking_stats(df=df, id_def=id_def, id_att = id_att,
                           time_steps=1,
                           headers = ["x", "y", "team_id", "player_id","time"], 
                           attack=True,threshold = 10)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1378">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="289b11c3-c25a-421f-b9fa-ab819c1f8c2f" data-root-id="1453"></div>
